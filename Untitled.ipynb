# %%
import pandas as pd

# %%
df = pd.read_excel("input_data/cc_twosteps.xlsx")

# %%
df.shape
# Out:
# (667533, 57)

# %%
df.head()
# Out:
#    c_track c_platform    c_month             c_artist              c_label  \
# 0  Victory    Tencent 2020-08-01  Two Steps From Hell  Two Steps From Hell
# 1  Victory    Tencent 2020-10-01  Two Steps From Hell  Two Steps From Hell
# 2  Victory    Tencent 2020-07-01  Two Steps From Hell  Two Steps From Hell
# 3  Victory    Tencent 2021-10-01  Two Steps From Hell  Two Steps From Hell
# 4  Victory    Tencent 2021-06-01  Two Steps From Hell  Two Steps From Hell
#
#      c_album  c_streams   c_revenue Transaction Date    Store  ... cc_track  \
# 0  Battlecry   25035467  9681.26611            44044  Tencent  ...  victory
# 1  Battlecry   23911227  9631.02332            44105  Tencent  ...  victory
# 2  Battlecry   25750249  9474.42947            44013  Tencent  ...  victory
# 3  Battlecry   19142657  9425.22498            44470  Tencent  ...  victory
# 4  Battlecry   20319740  9287.14809            44348  Tencent  ...  victory
#
# ...

# %%
df.iloc[:10].T
# Out:
#                                                       0  \
# c_track                                         Victory
# c_platform                                      Tencent
# c_month                             2020-08-01 00:00:00
# c_artist                            Two Steps From Hell
# c_label                             Two Steps From Hell
# c_album                                       Battlecry
# c_streams                                      25035467
# c_revenue                                    9681.26611
# Transaction Date                                  44044
# Store                                           Tencent
# Region                                               CN
# Artist Name                         Two Steps From Hell
# Label Name                          Two Steps From Hell
# Album Name                                    Battlecry
# Track Artist                        Two Steps From Hell
# UPC                                         18736262197
# ...

# %%
df["Client ID"].unique()
# Out:
# array([9])
